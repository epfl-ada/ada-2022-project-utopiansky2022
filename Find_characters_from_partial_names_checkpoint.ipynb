# %%
# !pip install stanza
# !pip install thefuzz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stanza in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.19.6)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (from stanza) (2.2.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (4.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: thefuzz in /usr/local/lib/python3.7/dist-packages (0.19.0)

# %%
import os 
import pandas as pd
import numpy as np
import stanza
from thefuzz import process
data_folder = '/content/sample_data/'
# Out:
# /usr/local/lib/python3.7/dist-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Loading the data obtained from the NLP pipeline:
df_1 = pd.read_csv(data_folder + "Plot_NLP_Analysis_0_14100.csv", sep='\t', header = None)
df_2 = pd.read_csv(data_folder + "Plot_NLP_Analysis_14101_23201.csv", sep='\t', header = None)
df_3 = pd.read_csv(data_folder + "Plot_NLP_Analysis23202-42302.csv", sep='\t', header = None)
df_1 = df_1.drop(columns=0)
df_2 = df_2.drop(columns=0)
df_3 = df_3.drop(columns=0)

# %%
clusters_df = pd.concat([df_1, df_2, df_3], ignore_index=True)
clusters_df.columns = ('Wikipedia movie ID', 'Character partial name', 'Agent Verbs', 'Patient Verbs', 'Attributes')

# %%
# Loading the data of character metadata
df_characters = pd.read_csv(data_folder +'character.metadata.tsv', sep='\t')
df_characters.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie release date', 'Character name', 
                         'Actor date of birth', 'Actor gender', 'Actor height (in meters)', 
                         'Actor ethnicity (Freebase ID)', 'Actor name', 'Actor age at movie release',
                        'Freebase character/actor map ID', 'Freebase character ID', 'Freebase actor ID']

# %%
# Loading the data of movie metadata
df_movie = pd.read_csv(data_folder +'movie.metadata.tsv', sep='\t')
df_movie.columns = ['Wikipedia movie ID', 'Freebase movie ID', 'Movie name',
                    'Movie release date', 'Movie box office revenue', 'Movie runtime',
                    'Movie languages (Freebase ID)', 'Movie countries (Freebase ID)', 
                    'Movie genres (Freebase ID)']

# %%
df_char_movie = pd.merge(left=df_characters, right=df_movie, how='inner', 
                         on= ['Wikipedia movie ID', 'Freebase movie ID', 
                              'Movie release date'])

# %%
df_char_movie = df_char_movie.reset_index(drop = True)

# %%
df_char_movie_names = df_char_movie[['Wikipedia movie ID','Character name']].dropna()
df_char_movie_names['All_names'] = df_char_movie_names.groupby(['Wikipedia movie ID'], 
            as_index = True)['Character name'].transform(lambda x: ','.join(x))
df_char_movie_names = df_char_movie_names[['Wikipedia movie ID', 'All_names']].drop_duplicates()
df_char_movie_names['All_names'] = [x.strip('()').split(',') for x in df_char_movie_names['All_names']]

# %%
clusters_df = clusters_df.merge(df_char_movie_names, how = 'inner', on = 'Wikipedia movie ID')
clusters_df.head(3)
# Out:
#    Wikipedia movie ID Character partial name                      Agent Verbs  \
# 0            20663735             Maranchery                              0.0
# 1            20663735              Manapally  ['accepts', 'arrives', 'tries']
# 2            20663735                   DYSP                              0.0
#
#   Patient Verbs            Attributes  \
# 0           0.0                   son
# 1           0.0  case crony post help
# 2           0.0                 crony
#
#                                            All_names
# 0  [M.K. Menon, Bharathan, Nandagopal Marar, Mara...
# 1  [M.K. Menon, Bharathan, Nandagopal Marar, Mara...
# 2  [M.K. Menon, Bharathan, Nandagopal Marar, Mara...

# %%
def matching(col1, col2):
    if process.extractOne(col1, list(col2))[1]>80:
        res = process.extractOne(col1, list(col2))[0]    
    else:
        res = 'Not found'
    return res

clusters_df['Full_name'] = clusters_df.apply(lambda x: matching(x['Character partial name'],
                                                                            x['All_names']), axis=1)
clusters_df.tail(50)
# Out:
#        Wikipedia movie ID Character partial name  \
# 35362            13348400                 Falcon
# 35363            13348400               Doberman
# 35364            20402406                Maribor
# 35365            20402406                 Behmen
# 35366            20402406               Debelzeq
# 35367            20402406                    Kay
# 35368            20402406                Hagamar
# 35369            20402406                Stephen
# 35370            20402406                Eckhart
# 35371            20402406                   Mila
# 35372            20402406                   Anna
# 35373            22762373                 Sakthi
# 35374            22762373                  Sachu
# 35375            22762373                   Vinu
# 35376            22762373              Sakthivel
# 35377            22762373            Kundalakesi
# 35378            22762373             Jayaganesh
# 35379            22762373                  Indhu
# 35380            22762373                  Mathi
# 35381            22762373                  Vivek
# 35382            22762373               Sakthi's
# 35383             8605430                  Titli
# 35384             8605430                  Rohit
# 35385             8605430                 Urmila
# 35386             8605430                 Rajesh
# 35387             8605430                Titli's
# 35388             8605430                 Shakti
# 35389             8605430                  Abani
# 35390             8605430             Meghadutam
# 35391             8605430                 Tagore
# 35392             8605430                   John
# 35393             4913923                  Tomas
# 35394             4913923                  Jacob
# 35395             4913923                   Dina
# 35396             4913923                  Lorch
# 35397             4913923                  Karen
# 35398             4913923                  Niels
# 35399             4913923               Benjamin
# 35400             4913923              Zhukovsky
# 35401             4913923                   King
# 35402            26261438                    Gor
# 35403            26261438                  Cabot
# 35404            26261438                 Talena
# 35405            26261438                 Koruba
# 35406            26261438                   King
# 35407            26261438                  Xenos
# 35408            26261438                    Hup
# 35409            26261438               Marlenus
# 35410            26261438                   Lara
# 35411            26261438                 Hunter
#
#                                              Agent Verbs  \
# 35362  ['heads', 'fears', 'finds', 'home', 'arrives',...
# 35363                                         ['chases']
# 35364                                                0.0
# 35365            ['enter', 'tries', 'continues', 'asks']
# 35366  ['returns', 'comes', 'beginning', 'comes', 'th...
# 35367       ['returns', 'picks', 'able', 'bury', 'tell']
# 35368                                       ['attempts']
# 35369                                                0.0
# 35370                           ['watch', 'gets', 'has']
# 35371                                                0.0
# 35372  ['becomes', 'explains', 'saves', 'appears', 'b...
# 35373  ['kid', 'doting', 'worried', 'has', 'falls', '...
# 35374             ['doting', 'worried', 'has', 'thinks']
# 35375              ['worried', 'has', 'meets', 'thinks']
# 35376                                           ['aids']
# 35377                                           ['aids']
# 35378                                                0.0
# 35379                               ['daughter', 'gets']
# 35380                                          ['works']
# 35381                                          ['works']
# 35382                                          ['works']
# 35383  ['girl', 'going', 'wants', 'returned', 'verge'...
# 35384   ['none', 'needs', 'outsider', 'feels', 'writes']
# 35385  ['shares', 'lovers', 'married', 'recites', 'wo...
# 35386                                                0.0
# 35387                                                0.0
# 35388                                                0.0
# 35389                                                0.0
# 35390                                                0.0
# 35391                                                0.0
# 35392                                         ['builds']
# 35393                      ['boy', 'encourages', 'back']
# 35394  ['boy', 'encourages', 'asks', 'suffers', 'appe...
# 35395  ['refuses', 'grows', 'refuses', 'slaps', 'reta...
# 35396                                ['grown', 'brings']
# 35397  ['runs', 'falls', 'sets', 'leaves', 'leaving',...
# 35398  ['like', 'rapes', 'staggers', 'decides', 'hangs']
# 35399                                            ['old']
# 35400  ['seen', 'returns', 'anarchist', 'going', 'says']
# 35401                                                0.0
# 35402                                                0.0
# 35403  ['activates', 'meets', 'protests', 'represents...
# 35404                            ['believes', 'triumph']
# 35405                                                0.0
# 35406                                  ['step', 'finds']
# 35407               ['attempts', 'unsuccessful', 'ends']
# 35408                                                0.0
# 35409                                      ['announces']
# 35410  ['desires', 'hire', 'betrays', 'tries', 'break...
# 35411                  ['finds', 'prepares', 'believes']
#
#                             Patient Verbs  \
# 35362                                 0.0
# 35363                                 0.0
# 35364                                 0.0
# 35365                         ['wounded']
# 35366                                 0.0
# 35367                                 0.0
# 35368                                 0.0
# 35369                                 0.0
# 35370                                 0.0
# 35371                                 0.0
# 35372                      ['possessing']
# 35373                                 0.0
# 35374                                 0.0
# 35375                                 0.0
# 35376                                 0.0
# 35377                                 0.0
# 35378                                 0.0
# 35379                                 0.0
# 35380                                 0.0
# 35381                                 0.0
# 35382                                 0.0
# 35383                       ['surprised']
# 35384                            ['made']
# 35385               ['surprised', 'made']
# 35386                                 0.0
# 35387                             ['set']
# 35388                                 0.0
# 35389                                 0.0
# 35390                                 0.0
# 35391                                 0.0
# 35392                                 0.0
# 35393                                 0.0
# 35394                                 0.0
# 35395                       ['bequeaths']
# 35396                                 0.0
# 35397                       ['bequeaths']
# 35398                                 0.0
# 35399                                 0.0
# 35400                        ['released']
# 35401                                 0.0
# 35402                                 0.0
# 35403  ['overjoyed', 'forced', 'brought']
# 35404                                 0.0
# 35405                       ['overjoyed']
# 35406                 ['married', 'sent']
# 35407                                 0.0
# 35408                                 0.0
# 35409                                 0.0
# 35410                                 0.0
# 35411                                 0.0
#
#                                               Attributes  \
# 35362     owner home dog relationship older goodbye band
# 35363                                                dog
# 35364                                               name
# 35365                                 sword bond actions
# 35366                         priest swindler altar fear
# 35367                   priest swindler altar sword able
# 35368                                           swindler
# 35369                                           swindler
# 35370                                         volunteers
# 35371                                           daughter
# 35372                                   tearful trusting
# 35373                       kid mother grandfather gifts
# 35374                                 mother grandfather
# 35375                                             father
# 35376                                              uncle
# 35377                                              uncle
# 35378                                    friend daughter
# 35379                                           daughter
# 35380                                      cousin cousin
# 35381                                             cousin
# 35382                                             cousin
# 35383          evolution girl mother father verge mother
# 35384          superstar none co-passenger outsider film
# 35385             mother lovers film married hill letter
# 35386                                              crush
# 35387                                             dreams
# 35388                                               poem
# 35389                                               poem
# 35390                                              verse
# 35391                                               poem
# 35392                                             fields
# 35393                                         boy friend
# 35394                                friend Family death
# 35395  father hand old ways fact accounting tendencie...
# 35396                                    departure death
# 35397                                    mother stepsons
# 35398                    stepsons deep ultimatum drunken
# 35399                                                old
# 35400                                          anarchist
# 35401                                               plot
# 35402                                         adventures
# 35403   ring return dangerous determined blow death ring
# 35404                                              lover
# 35405                                        townspeople
# 35406                                             father
# 35407                               priest attempts lack
# 35408                                           sidekick
# 35409                                       death killer
# 35410                            alliance attempt killer
# 35411                                              guard
#
#                                                All_names      Full_name
# 35362                [Martin Falcon, Jennie Lee, Daryle]  Martin Falcon
# 35363                [Martin Falcon, Jennie Lee, Daryle]      Not found
# 35364  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...      Not found
# 35365  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...      Not found
# 35366  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...       Debelzaq
# 35367  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...            Kay
# 35368  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...        Hagamar
# 35369  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...      Not found
# 35370  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...       Eckhardt
# 35371  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...      Not found
# 35372  [Kay, Behman von Bleibruck, Felson, Debelzaq, ...      Not found
# 35373                    [Kundalagesi, Sakthivel, Indhu]      Sakthivel
# 35374                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35375                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35376                    [Kundalagesi, Sakthivel, Indhu]      Sakthivel
# 35377                    [Kundalagesi, Sakthivel, Indhu]    Kundalagesi
# 35378                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35379                    [Kundalagesi, Sakthivel, Indhu]          Indhu
# 35380                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35381                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35382                    [Kundalagesi, Sakthivel, Indhu]      Not found
# 35383       [Urmila's husband, Rohit Roy, Urmila, Titli]          Titli
# 35384       [Urmila's husband, Rohit Roy, Urmila, Titli]      Rohit Roy
# 35385       [Urmila's husband, Rohit Roy, Urmila, Titli]         Urmila
# 35386       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35387       [Urmila's husband, Rohit Roy, Urmila, Titli]          Titli
# 35388       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35389       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35390       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35391       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35392       [Urmila's husband, Rohit Roy, Urmila, Titli]      Not found
# 35393                             [Leo Zhukovsky, Niels]      Not found
# 35394                             [Leo Zhukovsky, Niels]      Not found
# 35395                             [Leo Zhukovsky, Niels]      Not found
# 35396                             [Leo Zhukovsky, Niels]      Not found
# 35397                             [Leo Zhukovsky, Niels]      Not found
# 35398                             [Leo Zhukovsky, Niels]          Niels
# 35399                             [Leo Zhukovsky, Niels]      Not found
# 35400                             [Leo Zhukovsky, Niels]  Leo Zhukovsky
# 35401                             [Leo Zhukovsky, Niels]      Not found
# 35402  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...      Not found
# 35403  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...     Tarl Cabot
# 35404  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...         Talena
# 35405  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...            Kor
# 35406  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...      Not found
# 35407  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...          Xenos
# 35408  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...     Midget Hup
# 35409  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...       Marlenus
# 35410  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...     Queen Lara
# 35411  [Elder, Tarl Cabot, Queen Lara, Watney Smith, ...      Not found

# %%
clusters_df.to_csv(data_folder + "Characters_Matched_DF.csv", sep='\t', header=None)

# %% [markdown]
# # TO DO:
#
# - DROP ALL NOT FOUND CHARACTERS
# - PUT INFO TOGETHER FOR ALL ROWS CORRESPONDING TO THE SAME ACTOR
# - START ANALYSIS FROM HERE:
#     - WORK ON GOOGLE COLAB!
#     - EMPATH
#     - RATIO PATIENT/AGENT VERBS
#     - SEPARATE ANALYSIS PER GENRE
#     - TRY TO ADD THE MAIN CHARACTER

# %%
char_df = clusters_df.loc[clusters_df['Full_name'] != 'Not found']

# %%
len(char_df)
# Out:
# 17488

# %%
len(clusters_df)
# Out:
# 35412

# %%
char_df.head(10)
# Out:
#     Wikipedia movie ID Character partial name  \
# 0             20663735             Maranchery
# 3             20663735                  Menon
# 5             20663735            Induchoodan
# 12              595909                Michael
# 13              595909                  Lindy
# 15              595909           Chamberlains
# 20             5272176                Stevens
# 21             5272176                 Steven
# 22             1952976                 Dahlia
# 23             1952976                   Kyle
#
#                                           Agent Verbs          Patient Verbs  \
# 0                                                 0.0                    0.0
# 3                   ['refuses', 'regrets', 'suffers']  ['accused', 'judged']
# 5   ['loses', 'passes', 'thwarts', 'follow', 'fall...             ['framed']
# 12                ['holiday', 'uses', 'disintegrate']              ['found']
# 13            ['returns', 'saw', 'seems', 'insisted']   ['charged', 'found']
# 15                                     ['overturned']                    0.0
# 20                                         ['handed']                    0.0
# 21                                                0.0                    0.0
# 22  ['stands', 'wants', 'unstable', 'see', 'agrees...    ['reached', 'left']
# 23  ['wants', 'threatens', 'picks', 'picks', 'takes']                    0.0
#
#                                       Attributes  \
# 0                                            son
# 3                  judge jail corruption funeral
# 5   dead years state confrontations friend court
# 12                              pastor day faith
# 13                                          wife
# 15                                   convictions
# 20                                          home
# 21                                         house
# 22                                 girl unstable
# 23                                    ex-husband
#
#                                             All_names               Full_name
# 0   [M.K. Menon, Bharathan, Nandagopal Marar, Mara...  Marancheri Induchoodan
# 3   [M.K. Menon, Bharathan, Nandagopal Marar, Mara...              M.K. Menon
# 5   [M.K. Menon, Bharathan, Nandagopal Marar, Mara...  Marancheri Induchoodan
# 12  [Michael Chamberlain, Lindy Chamberlain, Magaz...     Michael Chamberlain
# 13  [Michael Chamberlain, Lindy Chamberlain, Magaz...       Lindy Chamberlain
# 15  [Michael Chamberlain, Lindy Chamberlain, Magaz...     Michael Chamberlain
# 20  [Kate Crawford, Vaughn Stevens, The First Lady...          Vaughn Stevens
# 21  [Kate Crawford, Vaughn Stevens, The First Lady...          Vaughn Stevens
# 22  [Mediator, Dahlia, Mr. Murray, Jeff Platzer, K...                  Dahlia
# 23  [Mediator, Dahlia, Mr. Murray, Jeff Platzer, K...           Kyle Williams

# %%
categories = ['Agent Verbs', 'Patient Verbs', 'Attributes']

for i,cat in enumerate(categories):
  rem = char_df[cat] == '0.0'
  char_df.loc[rem, cat] = char_df.loc[rem, cat].replace('0.0', '')
char_df['All_Agent_Verbs'] = char_df.groupby(['Full_name'])['Agent Verbs'].transform(lambda x: ','.join(x))
char_df['All_Patient_Verbs'] = char_df.groupby(['Full_name'])['Patient Verbs'].transform(lambda x: ','.join(x))
char_df['All_Attributes'] = char_df.groupby(['Full_name'])['Attributes'].transform(lambda x: ','.join(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
char_df = char_df[[	'Wikipedia movie ID', 'Full_name', 'All_Agent_Verbs', 'All_Patient_Verbs', 'All_Attributes']]

# %%
char_df
# Out:
#        Wikipedia movie ID               Full_name  \
# 0                20663735  Marancheri Induchoodan
# 3                20663735              M.K. Menon
# 5                20663735  Marancheri Induchoodan
# 12                 595909     Michael Chamberlain
# 13                 595909       Lindy Chamberlain
# ...                   ...                     ...
# 35405            26261438                     Kor
# 35407            26261438                   Xenos
# 35408            26261438              Midget Hup
# 35409            26261438                Marlenus
# 35410            26261438              Queen Lara
#
#                                          All_Agent_Verbs  \
# 0      ,['loses', 'passes', 'thwarts', 'follow', 'fal...
# 3                      ['refuses', 'regrets', 'suffers']
# 5      ,['loses', 'passes', 'thwarts', 'follow', 'fal...
# 12     ['holiday', 'uses', 'disintegrate'],['overturn...
# 13               ['returns', 'saw', 'seems', 'insisted']
# ...                                                  ...
# 35405
# 35407               ['attempts', 'unsuccessful', 'ends']
# 35408
# 35409                                      ['announces']
# 35410  ['desires', 'hire', 'betrays', 'tries', 'break...
#
#            All_Patient_Verbs                                    All_Attributes
# 0                ,['framed']  son,dead years state confrontations friend court
# 3      ['accused', 'judged']                     judge jail corruption funeral
# 5                ,['framed']  son,dead years state confrontations friend court
# 12                ['found'],                      pastor day faith,convictions
# 13      ['charged', 'found']                                              wife
# ...                      ...                                               ...
# 35405          ['overjoyed']                                       townspeople
# 35407                                                     priest attempts lack
# 35408                                                                 sidekick
# 35409                                                             death killer
# 35410                                                  alliance attempt killer
#
# [17488 rows x 5 columns]

# %%
char_df.to_csv(data_folder + "Characters_Matched_DF_Clean.csv", sep='\t', header=None)

# %% [markdown]
# From here all testing stuff

# %%
clusters_df_test = clusters_df.head(150)

# %%
# Python env: pip install thefuzz
# Anaconda env: pip install thefuzz
# -> thefuzz is not yet available on Anaconda (2021-09-18)
# -> you can use the old package: conda install -c conda-forge fuzzywuzzy

#df_char_movie_test = df_char_movie[df_char_movie['Wikipedia movie ID' == 31186339]]#'23890098']]or 'Wikipedia movie ID' =='31186339'or 'Wikipedia movie ID' =='20663735'or 'Wikipedia movie ID' =='2231378']
#df_char_movie_test
ids = clusters_df_test['Wikipedia movie ID'].unique()
df_char_movie_test = df_char_movie[df_char_movie['Wikipedia movie ID'].isin(ids)]

# %%
df_char_movie_test2 = df_char_movie_test[['Wikipedia movie ID','Character name']].dropna()
df_char_movie_test2['All_names'] = df_char_movie_test2.groupby(['Wikipedia movie ID'], 
            as_index = True)['Character name'].transform(lambda x: ','.join(x))
df_char_movie_test2['All_names'] = [x.strip('()').split(',') for x in df_char_movie_test2['All_names']]
df_char_movie_test2 = df_char_movie_test2[['Wikipedia movie ID', 'All_names']].drop_duplicates()

# %%
clusters_df_test2 = clusters_df_test.merge(df_char_movie_test2, how = 'right', on = 'Wikipedia movie ID')
clusters_df_test2.head(15)
# Out:
#     Wikipedia movie ID Character partial name  \
# 0             20663735             Maranchery
# 1             20663735              Manapally
# 2             20663735                   DYSP
# 3             20663735                  Menon
# 4             20663735                 Moopil
# 5             20663735            Induchoodan
# 6             20663735                Nambiar
# 7             20663735                Mooppil
# 8             20663735                 Kanaka
# 9             20663735           Chandrabhanu
# 10            20663735           Jayakrishnan
# 11            20663735              Indulekha
# 12            15224586                   Minh
# 13            15224586                    Duc
# 14            24225279                 Mickey
#
#                                           Agent Verbs          Patient Verbs  \
# 0                                                 0.0                    0.0
# 1                     ['accepts', 'arrives', 'tries']                    0.0
# 2                                                 0.0                    0.0
# 3                   ['refuses', 'regrets', 'suffers']  ['accused', 'judged']
# 4                                                 0.0                    0.0
# 5   ['loses', 'passes', 'thwarts', 'follow', 'fall...             ['framed']
# 6                                    ['Ramakrishnan']                    0.0
# 7                                                 0.0                    0.0
# 8                                                 0.0                    0.0
# 9                                                 0.0                    0.0
# 10                                                0.0                    0.0
# 11                                                0.0              ['found']
# 12                                         ['silent']              ['drawn']
# 13                                          ['falls']                    0.0
# 14                                                0.0                    0.0
#
#                                       Attributes  \
# 0                                            son
# 1                           case crony post help
# 2                                          crony
# 3                  judge jail corruption funeral
# 4                                            son
# 5   dead years state confrontations friend court
# 6                                rituals funeral
# 7                                daughter minded
# 8                                           girl
# 9                                          truth
# 10                                        friend
# 11                                     parentage
# 12                               silent solitary
# 13                                        friend
# 14                                  boyfriend ex
#
#                                             All_names
# 0   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 1   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 2   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 3   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 4   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 5   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 6   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 7   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 8   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 9   M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 10  M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 11  M.K. Menon,Bharathan,Nandagopal Marar,Maranche...
# 12                   Addie,Gunnery Sergeant Jim Lance
# 13                   Addie,Gunnery Sergeant Jim Lance
# 14                                      Miss Lombardo

# %%
def matching(col1, col2):
    if process.extractOne(col1, list(col2))[1]>80:
        res = process.extractOne(col1, list(col2))[0]    
    else:
        res = 'Not found'
    return res

clusters_df_test2['Full_name'] = clusters_df_test2.apply(lambda x: matching(x['Character partial name'],
                                                                            x['All_names']), axis=1)
clusters_df_test2.tail(50)
# Out:
#      Wikipedia movie ID Character partial name  \
# 85               447194                  Ahtur
# 86               447194                 Samson
# 87               447194                  Dagon
# 88             31186339               Primrose
# 89             31186339                Katniss
# 90             31186339                  Peeta
# 91             31186339               Haymitch
# 92             31186339                 Caesar
# 93             31186339                    Rue
# 94              8388648                 Madhav
# 95              8388648                 Sreenu
# 96              8388648                Amrutha
# 97              1335380              Katherine
# 98              1335380                  Kitty
# 99              1335380                  Karen
# 100             1335380                    Dov
# 101             1335380                  Irgun
# 102             1335380                    Ari
# 103             1335380                  Akiva
# 104             1335380                  Ari's
# 105             1335380                  Barak
# 106             1335380                    Gan
# 107             1335380                   Taha
# 108             2254491                   Sita
# 109             2254491                  Anita
# 110             2254491                Preetam
# 111            10644072               Bhagwaan
# 112            10644072                Govinda
# 113            10644072                Swaroop
# 114            10644072                 Shambu
# 115            10644072                  Bijli
# 116            10644072                  Madhu
# 117            10644072                  Geeta
# 118            12978934                   Beth
# 119            12978934                    Ben
# 120            12978934                Vincent
# 121            12978934               Jonathan
# 122            12978934                    Sam
# 123            12978934              Cappadora
# 124            15072401                  Colby
# 125            15072401                 Lowell
# 126            15072401                 Ulrich
# 127            15072401                   Alan
# 128            33269085               Ranchhod
# 129            33269085                      à
# 130            33269085                Namrata
# 131            33269085                   Ritu
# 132            33269085                  Roger
# 133            33269085                  Patel
# 134            33269085                 Sunder
#
#                                            Agent Verbs  \
# 85                                         ['decides']
# 86                ['loses', 'becomes', 'rips', 'asks']
# 87                               ['collapses', 'lies']
# 88                                                 0.0
# 89   ['volunteers', 'survives', 'drops', 'has', 'ru...
# 90   ['tribute', 'reveals', 'meant', 'forms', 'begs...
# 91                                   ['able', 'warns']
# 92                                                 0.0
# 93                          ['draws', 'cares', 'draw']
# 94   ['playing', 'friends', 'escapes', 'works', 'se...
# 95   ['tries', 'loses', 'convinces', 'gets', 'agree...
# 96   ['returns', 'holds', 'tries', 'thinks', 'one',...
# 97                                       ['volunteer']
# 98                    ['volunteer', 'grown', 'fallen']
# 99   ['proclaims', 'Sonderkommando', 'ill', 'gone',...
# 100  ['proclaims', 'goes', 'bombs', 'turns', 'assur...
# 101                                         ['damage']
# 102  ['obtains', 'threatens', 'devise', 'receives',...
# 103  ['forces', 'Sonderkommando', 'ill', 'use', 'ma...
# 104        ['Sonderkommando', 'ill', 'use', 'manages']
# 105        ['Sonderkommando', 'ill', 'use', 'manages']
# 106                                                0.0
# 107                                        ['mukhtar']
# 108                   ['suspicious', 'agree', 'hires']
# 109               ['marry', 'befriends', 'recognizes']
# 110                                ['meets', 'leaves']
# 111  ['turns', 'falls', 'vows', 'does', 'chances', ...
# 112  ['become', 'mistakes', 'remaining', 'invites',...
# 113  ['falls', 'does', 'claim', 'hears', 'soul', 'h...
# 114  ['steal', 'lusts', 'sworn', 'dumps', 'escaped'...
# 115  ['insists', 'streetwalker', 'spills', 'worker'...
# 116                  ['reciprocates', 'comes', 'help']
# 117                    ['discover', 'goes', 'realise']
# 118                               ['goes', 'neglects']
# 119        ['vanishes', 'gone', 'produces', 'reveals']
# 120                                          ['finds']
# 121                                                0.0
# 122                                ['vanishes', 'son']
# 123                            ['accepted', 'decides']
# 124                                                0.0
# 125                                                0.0
# 126                                                0.0
# 127                                      ['reappears']
# 128                                            ['man']
# 129                                                0.0
# 130                                                0.0
# 131                                        ['informs']
# 132                                       ['arranges']
# 133                                                0.0
# 134                                                0.0
#
#                                          Patient Verbs  \
# 85                                                 0.0
# 86                     ['engaged', 'taken', 'blinded']
# 87                                                 0.0
# 88                                          ['chosen']
# 89            ['gave', 'taken', 'warned', 'presented']
# 90                                                 0.0
# 91                                                 0.0
# 92                                                 0.0
# 93                                                 0.0
# 94                                                 0.0
# 95                                            ['seen']
# 96                                      ['questioned']
# 97                                                 0.0
# 98                                         ['brought']
# 99   ['freed', 'contacted', 'raped', 'found', 'buri...
# 100                                                0.0
# 101                                                0.0
# 102                              ['raised', 'wounded']
# 103  ['freed', 'contacted', 'raped', 'disowned', 'a...
# 104           ['freed', 'contacted', 'raped', 'found']
# 105           ['freed', 'contacted', 'raped', 'found']
# 106                                                0.0
# 107                                          ['found']
# 108                                                0.0
# 109                                     ['controlled']
# 110                                ['kept', 'worried']
# 111                    ['spills', 'killed', 'injured']
# 112                                                0.0
# 113                   ['hears', 'returned', 'injured']
# 114                                      ['convicted']
# 115                                                0.0
# 116                                                0.0
# 117                                    ['interrupted']
# 118                                      ['convinced']
# 119                                      ['kidnapped']
# 120                                       ['forgiven']
# 121                                                0.0
# 122                                                0.0
# 123                                                0.0
# 124                                                0.0
# 125                                                0.0
# 126                                                0.0
# 127                                                0.0
# 128                                                0.0
# 129                                                0.0
# 130                                                0.0
# 131                                                0.0
# 132                                                0.0
# 133                                                0.0
# 134                                                0.0
#
#                                             Attributes  \
# 85                             high chariot war defeat
# 86                                  hands love passing
# 87                                              temple
# 88                                                 old
# 89                                         sister love
# 90                           tribute mobile victorious
# 91                        victor advice able star rule
# 92                                        interview TV
# 93                                                body
# 94               friends neighbours football love love
# 95                         accident house bride father
# 96                                      love one bride
# 97                                               Nurse
# 98                                       Nurse chagrin
# 99                          young beau father ecstatic
# 100                                               beau
# 101                                    address members
# 102                                              uncle
# 103                          uncle head uncle hundreds
# 104                                  father diplomatic
# 105                                  father diplomatic
# 106                                            village
# 107                                        friend body
# 108                                    aunt suspicious
# 109                                          attitudes
# 110                                    sister feelings
# 111  soul source inspiration home revenge territory...
# 112  son son young young brave little legs murder w...
# 113  city money education city soul wife ecstatic m...
# 114  gang assault gang men activities crime empire ...
# 115  streetwalker worker sex fraud attraction behav...
# 116                 reporter newspaper crime exhausted
# 117                                     sister wedding
# 118                             husband reunion school
# 119                            son re-integration best
# 120                                           children
# 121                                           children
# 122                                                son
# 123                                             family
# 124                                            fortune
# 125                                     fortune estate
# 126                                             estate
# 127                                             grudge
# 128                             man arrogant self area
# 129                                     magnate estate
# 130                                 daughters marriage
# 131                                          daughters
# 132                                     overprotective
# 133                                   man professional
# 134          mate soul part part professional property
#
#                                              All_names  \
# 85   [Haisham, Delilah, Samson, The Saran of Gaza, ...
# 86   [Haisham, Delilah, Samson, The Saran of Gaza, ...
# 87   [Haisham, Delilah, Samson, The Saran of Gaza, ...
# 88   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 89   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 90   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 91   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 92   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 93   [Foxface, Katniss Everdeen, Peeta Mellark, Eff...
# 94                      [Madhav, Amrutha, Hero friend]
# 95                      [Madhav, Amrutha, Hero friend]
# 96                      [Madhav, Amrutha, Hero friend]
# 97                        [Ari Ben Canaan, Dov Landau]
# 98                        [Ari Ben Canaan, Dov Landau]
# 99                        [Ari Ben Canaan, Dov Landau]
# 100                       [Ari Ben Canaan, Dov Landau]
# 101                       [Ari Ben Canaan, Dov Landau]
# 102                       [Ari Ben Canaan, Dov Landau]
# 103                       [Ari Ben Canaan, Dov Landau]
# 104                       [Ari Ben Canaan, Dov Landau]
# 105                       [Ari Ben Canaan, Dov Landau]
# 106                       [Ari Ben Canaan, Dov Landau]
# 107                       [Ari Ben Canaan, Dov Landau]
# 108  [Preetam Kumar, Anita Verma, Johny, Singer, Se...
# 109  [Preetam Kumar, Anita Verma, Johny, Singer, Se...
# 110  [Preetam Kumar, Anita Verma, Johny, Singer, Se...
# 111                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 112                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 113                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 114                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 115                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 116                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 117                [Bhagwaan Dada, Madhu, Nirmaladevi]
# 118  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 119  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 120  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 121  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 122  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 123  [Vincent Cappadora - Age 16, Sam Karras / Ben ...
# 124  [Henrietta Lowell, Charlie Chan, Alice Lowell,...
# 125  [Henrietta Lowell, Charlie Chan, Alice Lowell,...
# 126  [Henrietta Lowell, Charlie Chan, Alice Lowell,...
# 127  [Henrietta Lowell, Charlie Chan, Alice Lowell,...
# 128                       [Sunder Kapoor, Kamla Patel]
# 129                       [Sunder Kapoor, Kamla Patel]
# 130                       [Sunder Kapoor, Kamla Patel]
# 131                       [Sunder Kapoor, Kamla Patel]
# 132                       [Sunder Kapoor, Kamla Patel]
# 133                       [Sunder Kapoor, Kamla Patel]
# 134                       [Sunder Kapoor, Kamla Patel]
#
#                       Full_name
# 85                    Not found
# 86                       Samson
# 87                    Not found
# 88            Primrose Everdeen
# 89             Katniss Everdeen
# 90                Peeta Mellark
# 91           Haymitch Abernathy
# 92            Caesar Flickerman
# 93                          Rue
# 94                       Madhav
# 95                    Not found
# 96                      Amrutha
# 97                    Not found
# 98                    Not found
# 99                    Not found
# 100                  Dov Landau
# 101                   Not found
# 102              Ari Ben Canaan
# 103                   Not found
# 104              Ari Ben Canaan
# 105                   Not found
# 106                   Not found
# 107                   Not found
# 108                   Not found
# 109                 Anita Verma
# 110               Preetam Kumar
# 111               Bhagwaan Dada
# 112                   Not found
# 113                   Not found
# 114                   Not found
# 115                   Not found
# 116                       Madhu
# 117                   Not found
# 118              Beth Cappadora
# 119       Ben Cappadora - Age 3
# 120  Vincent Cappadora - Age 16
# 121                   Not found
# 122                   Not found
# 123               Pat Cappadora
# 124                   Not found
# 125            Henrietta Lowell
# 126                      Ulrich
# 127                   Not found
# 128                   Not found
# 129                   Not found
# 130                   Not found
# 131                   Not found
# 132                   Not found
# 133                 Kamla Patel
# 134               Sunder Kapoor

# %%
#OTHER TESTS TO USE IN CASE WE WANT TO IMPROVE THE CODE


''' 1- TRYING THE MAP FUNCTION
best_char = lambda x: process.extractOne(x, df_char_movie_test["Character name"])[2]  # See note below
clusters_df_test['Char'] = df_char_movie_test.loc[clusters_df_test["Character partial name"].map(best_char).values, "Character name"].values

2- GROUPBY AND DO LIKE CAMILLE
#res = [process.extractOne(elem, char_movie_31186339) for elem in clusters_df_31186339[0:6]]
dfm = pd.DataFrame(clusters_df_31186339.apply(lambda x: process.extractOne(x, char_movie_31186339))
                               .tolist(), columns=["Character name", "ratio", "best_id"])
# Need to find the correlation between both dataframes : in clusters_df, there are only names and in df_char_movie there are full character names:
# However, process.extractOne is comparing one string with a list of strings : we need to group by movie and compare each element of the group with each element of the other group:
clusters = clusters_df.groupby(['Wikipedia movie ID'])['Character partial name']
char_movies = df_char_movie.groupby(['Wikipedia movie ID'])['Character name']
dfm = pd.DataFrame(clusters.apply(lambda x: [process.extractOne(elem, [group.values for name, group in char_movies]) for elem in x])
                               .tolist(), columns=['Character name', 'ratio', 'best_id']) #score_cutoff = 50?
'''
# Out:
# ' 1- TRYING THE MAP FUNCTION\nbest_char = lambda x: process.extractOne(x, df_char_movie_test["Character name"])[2]  # See note below\nclusters_df_test[\'Char\'] = df_char_movie_test.loc[clusters_df_test["Character partial name"].map(best_char).values, "Character name"].values\n\n2- GROUPBY AND DO LIKE CAMILLE\n#res = [process.extractOne(elem, char_movie_31186339) for elem in clusters_df_31186339[0:6]]\ndfm = pd.DataFrame(clusters_df_31186339.apply(lambda x: process.extractOne(x, char_movie_31186339))\n                               .tolist(), columns=["Character name", "ratio", "best_id"])\n# Need to find the correlation between both dataframes : in clusters_df, there are only names and in df_char_movie there are full character names:\n# However, process.extractOne is comparing one string with a list of strings : we need to group by movie and compare each element of the group with each element of the other group:\nclusters = clusters_df.groupby([\'Wikipedia movie ID\'])[\'Character partial name\']\nchar_movies = df_char_movie.groupby([\'Wikipedia movie ID\'])[\'Character name\']\ndfm = pd.DataFrame(clusters.apply(lambda x: [process.extractOne(elem, [group.values for name, group in char_movies]) for elem in x])\n                               .tolist(), columns=[\'Character name\', \'ratio\', \'best_id\']) #score_cutoff = 50?\n'

# %%
clusters_df_test3['All_names'][127]
# Out:
# ['Henrietta Lowell',
#  'Charlie Chan',
#  'Alice Lowell',
#  'Dick Williams',
#  'Fred Gage',
#  'Janice Gage',
#  'Baxter',
#  'Warren T. Phelps',
#  'Ulrich',
#  'Carlotta']
